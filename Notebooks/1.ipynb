# %% [markdown]
# # Importer les données

# %% [markdown]
# La première étape consiste à importer les données. On se sert de Pandas et de la fonctuon `read_csv()`.
# La fonction `.head()` permet de visualiser les premières lignes du jeux de données.

# %%
import pandas as pd

# %%
filename = '../Penn_State_PA_2012.gzip'
df = pd.read_csv(filename, encoding='utf-8', compression='gzip', index_col='timestamp', parse_dates=True)
df.index = df.index.tz_localize('UTC').tz_convert('US/Eastern')
df.head()
# Out:
#                            Year  Day number  Month  Day  Hour  Minute     dt  \
# timestamp
# 2012-01-01 00:00:00-05:00  2012           1      1    1     5       1  5.017
# 2012-01-01 00:01:00-05:00  2012           1      1    1     5       2  5.033
# 2012-01-01 00:02:00-05:00  2012           1      1    1     5       3  5.050
# 2012-01-01 00:03:00-05:00  2012           1      1    1     5       4  5.067
# 2012-01-01 00:04:00-05:00  2012           1      1    1     5       5  5.083
#
#                               zen  dw_solar  dw_solar_Flag      ...        \
# timestamp                                                       ...
# 2012-01-01 00:00:00-05:00  162.07      -1.5              0      ...
# 2012-01-01 00:01:00-05:00  162.10      -1.5              0      ...
# 2012-01-01 00:02:00-05:00  162.14      -1.6              0      ...
# 2012-01-01 00:03:00-05:00  162.17      -1.6              0      ...
# 2012-01-01 00:04:00-05:00  162.19      -1.6              0      ...
#
# ...
